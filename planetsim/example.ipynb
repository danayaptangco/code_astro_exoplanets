# %%
from run_sim import Planet, Star, Transit

# %%
# initialize planet and star
planet1 = Planet(radius=.10, orbital_period=2)  # 
star1 = Star(radius=1, mass=1, stype='B')  # example star with r = 1.0 solar radius and m = 1.0 solar mass

transit1 = Transit(planet1, star1)  # initialize star system
transit1.make_lightcurve()  # generate the lightcurve with batman
transit1.make_snapshot(0)  # create a snapshot of the system at time = 0
transit1.make_animation()  # generate animation of full transit
# Out:
# Star fraction of plot: 0.12473394990057987
# 'planet_transit.gif'
